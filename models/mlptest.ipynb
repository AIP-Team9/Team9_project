# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/2024_1.csv', encoding='euc-kr')

# Shuffle the data
data = data.sample(frac=1).reset_index(drop=True)

print(data.head())
# Define split ratios
train_ratio = 0.7
validation_ratio = 0.15
test_ratio = 0.15

# Split the data into training, validation, and testing sets
train_data, temp_data = train_test_split(data, test_size=(1 - train_ratio))
val_data, test_data = train_test_split(temp_data, test_size=test_ratio/(test_ratio + validation_ratio))

# Save the splits to CSV files if needed
train_data.to_csv("train_data.csv", index=False)
val_data.to_csv("val_data.csv", index=False)
test_data.to_csv("test_data.csv", index=False)
# Out:
#      관측지점              관측시간  관측온도  관측습도    관측기압  관측풍속   관측풍향  관측최대풍속  관측미세먼지  \
# 0   예산_주거  2024-01-03 23:10   0.0  83.8  1019.2   0.2  310.7     0.8    41.8
# 1   청주_주거  2024-01-26 20:10  -0.6  73.4  1021.6   0.2   58.5     0.4    71.0
# 2  인천_주거2  2024-01-23 13:40  -9.5  51.4  1026.0   1.2  330.9     3.9    17.0
# 3  충주_주거1  2024-01-08 11:20  -3.5  48.9  1016.5   0.7  276.6     1.5    16.0
# 4   세종_도시  2024-01-13 06:30  -3.0  71.9  1015.9   0.1  353.1     0.5    29.1
#
#    관측초미세먼지  ...  (AVOC)배관관측온도  (BVOC)관측온도  (BVOC)관측습도  (BVOC)관측기압  (BVOC)관측풍속  \
# 0     39.0  ...         103.7        -0.2        84.2      1019.2         0.3
# 1     62.6  ...         104.5        -0.6        73.3      1021.6         0.2
# 2     12.6  ...         106.3        -9.5        51.6      1025.9         1.3
# 3     12.5  ...         107.9        -3.6        49.0      1016.6         0.7
# 4     20.9  ...         101.1        -3.0        72.1      1016.0         0.2
#
#    (BVOC)관측풍향  (BVOC)관측최대풍속  (BVOC)관측미세먼지  (BVOC)관측초미세먼지  (BVOC)관측극초미세먼지
# 0       267.3           0.8           8.0            7.5             7.2
# 1        64.3           0.4          28.4           23.6            22.9
# 2       330.0           4.3           3.8            2.6             2.3
# 3       257.3           1.9           3.2            2.6             2.5
# 4       270.6           0.6           6.0            4.5             4.6
#
# [5 rows x 31 columns]

# %% [markdown]
# # **MLP test1, lr = 0.001 and 300 epoch**

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
#CPU 혹은 GPU 사용, GPU우선적으로 사용가능
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 데이터 불러오기 (전처리 완료된 데이터라고 가정)
# 이전의 전러치 코드에서 저장한 데이터 사용, val_data는  아마 eval에서 사용예정
train_data = pd.read_csv("train_data.csv")
test_data = pd.read_csv("test_data.csv")

# 특성과 타겟 변수 분리
X_train = train_data.drop(columns=["관측미세먼지"]).values
X_test = test_data.drop(columns=["관측미세먼지"]).values
y_train = train_data["관측미세먼지"].values
y_test = test_data["관측미세먼지"].values

# 각각 train과 test를 알맞게 데이터와 매치, 관측 지점과 관측시간은 숫자형이 아니라서 일단 배제,추후 필요없는 특성이면 drop, 아니라면 다른 전처리 필요
X_train = train_data.drop(columns=["관측미세먼지", "관측지점", "관측시간"]).apply(pd.to_numeric, errors='coerce').fillna(0).values
X_test = test_data.drop(columns=["관측미세먼지", "관측지점", "관측시간"]).apply(pd.to_numeric, errors='coerce').fillna(0).values
y_train = train_data["관측미세먼지"].apply(pd.to_numeric, errors='coerce').fillna(0).values
y_test = test_data["관측미세먼지"].apply(pd.to_numeric, errors='coerce').fillna(0).values

# 스케일링
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# 데이터셋 축소, 시연에서는 10%만 사용, 이후에는 숫자만 조정으로 데이터사이즈 조정,
X_train, _, y_train, _ = train_test_split(X_train, y_train, train_size=0.1, random_state=42)
X_test, _, y_test, _ = train_test_split(X_test, y_test, train_size=0.1, random_state=42)

# Tensor로 변환
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)



# DataLoader 정의
train_dataset = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# 모델 정의
class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(X_train.shape[1], 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 1)
        self.dropout = nn.Dropout(0.2) #overfiting 방지를 위한 drop

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = self.dropout(x)
        x = torch.relu(self.fc2(x))
        x = self.dropout(x)
        x = self.fc3(x)
        return x

    #현재는 미세먼지 농도 "수치"를 예측하는것인 모델이고
    #"수치"를 또 분류하려면 layer를 추가하면됨 ex)softmax(다중분류  ex:저 중 고) , binary(이진분류 ex:저 고)


model = MLP()

# 손실 함수, 옵티마이저 정의
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)   # 0.01로 20인경우 5번째부터 verfiiting 발생  0.001에 epoch 20이 적당해보임

train_losses = []
test_losses = []
# 모델 학습
num_epochs = 300
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for X_batch, y_batch in train_loader:
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * X_batch.size(0)

    epoch_loss = running_loss / len(train_loader.dataset)
    train_losses.append(epoch_loss)  # Append training loss

    #모델 성능 임시 테스트용, 삭제해도 무관
    model.eval()
    with torch.no_grad():
        test_outputs = model(X_test)
        test_loss = criterion(test_outputs, y_test)

    test_losses.append(test_loss.item())  # Append test loss

    print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {epoch_loss:.4f}, Test Loss: {test_loss.item():.4f}')

# Plotting training and test losses
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Losses')
plt.legend()
plt.grid(True)
plt.show()


# 예측 함수 정의
def predict(model, X_test):
    model.eval()
    with torch.no_grad():
        y_pred = model(X_test)
    return y_pred.numpy()

# 예측후 결과 저장
predicted_values = predict(model, X_test)

#결과를 npy값으로 저장, 다음파일에서 사용가능
np.save('MLP.npy', predicted_values)
# Out:
# Epoch [1/300], Loss: 202.5556, Test Loss: 26.3067
# Epoch [2/300], Loss: 41.5825, Test Loss: 9.8136
# Epoch [3/300], Loss: 30.6429, Test Loss: 9.1648
# Epoch [4/300], Loss: 27.5994, Test Loss: 9.3529
# Epoch [5/300], Loss: 26.8370, Test Loss: 8.7244
# Epoch [6/300], Loss: 26.6340, Test Loss: 8.7742
# Epoch [7/300], Loss: 27.1397, Test Loss: 8.1595
# Epoch [8/300], Loss: 25.3927, Test Loss: 9.8308
# Epoch [9/300], Loss: 24.0672, Test Loss: 7.8979
# Epoch [10/300], Loss: 23.8733, Test Loss: 7.8510
# Epoch [11/300], Loss: 22.7175, Test Loss: 9.6344
# Epoch [12/300], Loss: 22.4831, Test Loss: 8.1040
# Epoch [13/300], Loss: 21.7372, Test Loss: 7.8434
# Epoch [14/300], Loss: 22.2847, Test Loss: 8.1698
# Epoch [15/300], Loss: 21.8390, Test Loss: 8.2337
# Epoch [16/300], Loss: 21.1057, Test Loss: 7.5006
# Epoch [17/300], Loss: 21.1577, Test Loss: 8.3742
# Epoch [18/300], Loss: 20.2343, Test Loss: 8.0053
# Epoch [19/300], Loss: 19.7358, Test Loss: 9.9028
# Epoch [20/300], Loss: 20.7914, Test Loss: 7.4361
# Epoch [21/300], Loss: 19.6343, Test Loss: 7.0301
# Epoch [22/300], Loss: 19.2374, Test Loss: 8.5778
# Epoch [23/300], Loss: 19.1328, Test Loss: 7.5131
# Epoch [24/300], Loss: 18.5839, Test Loss: 7.9947
# Epoch [25/300], Loss: 19.6903, Test Loss: 8.5994
# Epoch [26/300], Loss: 20.2395, Test Loss: 6.7800
# Epoch [27/300], Loss: 17.5284, Test Loss: 7.1233
# Epoch [28/300], Loss: 18.5221, Test Loss: 8.0408
# Epoch [29/300], Loss: 17.6675, Test Loss: 6.6665
# Epoch [30/300], Loss: 17.4424, Test Loss: 8.2390
# Epoch [31/300], Loss: 17.7673, Test Loss: 7.2887
# Epoch [32/300], Loss: 17.1288, Test Loss: 7.1797
# Epoch [33/300], Loss: 17.5290, Test Loss: 7.7156
# Epoch [34/300], Loss: 17.4261, Test Loss: 7.3555
# Epoch [35/300], Loss: 16.9356, Test Loss: 7.5010
# Epoch [36/300], Loss: 16.9518, Test Loss: 6.9143
# Epoch [37/300], Loss: 16.7144, Test Loss: 9.0955
# Epoch [38/300], Loss: 17.8615, Test Loss: 6.7244
# Epoch [39/300], Loss: 16.7376, Test Loss: 6.6287
# Epoch [40/300], Loss: 16.4042, Test Loss: 6.7418
# Epoch [41/300], Loss: 15.7571, Test Loss: 6.9941
# Epoch [42/300], Loss: 15.6505, Test Loss: 7.3583
# Epoch [43/300], Loss: 15.7633, Test Loss: 6.8485
# Epoch [44/300], Loss: 15.4734, Test Loss: 7.3419
# Epoch [45/300], Loss: 15.0465, Test Loss: 6.8527
# Epoch [46/300], Loss: 16.3372, Test Loss: 7.1931
# Epoch [47/300], Loss: 15.1337, Test Loss: 6.6978
# Epoch [48/300], Loss: 14.2968, Test Loss: 7.0852
# Epoch [49/300], Loss: 15.2905, Test Loss: 7.1892
# Epoch [50/300], Loss: 14.6971, Test Loss: 7.1985
# Epoch [51/300], Loss: 14.5608, Test Loss: 7.3243
# Epoch [52/300], Loss: 14.8575, Test Loss: 7.4106
# Epoch [53/300], Loss: 14.5730, Test Loss: 7.0145
# Epoch [54/300], Loss: 14.1158, Test Loss: 6.9294
# Epoch [55/300], Loss: 13.9087, Test Loss: 7.2173
# Epoch [56/300], Loss: 15.1071, Test Loss: 6.6014
# Epoch [57/300], Loss: 14.0995, Test Loss: 6.8432
# Epoch [58/300], Loss: 13.9634, Test Loss: 6.9841
# Epoch [59/300], Loss: 13.6145, Test Loss: 6.9381
# Epoch [60/300], Loss: 14.1023, Test Loss: 7.0466
# Epoch [61/300], Loss: 12.8002, Test Loss: 7.2650
# Epoch [62/300], Loss: 13.1908, Test Loss: 8.0113
# Epoch [63/300], Loss: 14.7915, Test Loss: 6.6899
# Epoch [64/300], Loss: 13.6996, Test Loss: 6.4484
# Epoch [65/300], Loss: 13.5412, Test Loss: 6.7017
# Epoch [66/300], Loss: 13.2807, Test Loss: 6.8693
# Epoch [67/300], Loss: 12.5652, Test Loss: 7.7515
# Epoch [68/300], Loss: 13.3279, Test Loss: 6.7420
# Epoch [69/300], Loss: 13.2689, Test Loss: 6.8111
# Epoch [70/300], Loss: 13.2552, Test Loss: 6.7701
# Epoch [71/300], Loss: 12.7400, Test Loss: 6.5070
# Epoch [72/300], Loss: 12.9317, Test Loss: 6.5970
# Epoch [73/300], Loss: 12.9591, Test Loss: 7.2722
# Epoch [74/300], Loss: 12.6858, Test Loss: 6.3213
# Epoch [75/300], Loss: 13.0159, Test Loss: 6.7820
# Epoch [76/300], Loss: 12.5360, Test Loss: 6.5580
# Epoch [77/300], Loss: 12.6160, Test Loss: 6.8966
# Epoch [78/300], Loss: 13.3081, Test Loss: 10.5309
# Epoch [79/300], Loss: 12.8730, Test Loss: 6.7496
# Epoch [80/300], Loss: 11.8852, Test Loss: 7.0308
# Epoch [81/300], Loss: 12.4824, Test Loss: 7.1098
# Epoch [82/300], Loss: 12.6539, Test Loss: 6.6183
# Epoch [83/300], Loss: 11.9764, Test Loss: 6.6522
# Epoch [84/300], Loss: 12.7548, Test Loss: 7.1010
# Epoch [85/300], Loss: 12.0693, Test Loss: 7.5170
# Epoch [86/300], Loss: 11.6656, Test Loss: 6.7705
# Epoch [87/300], Loss: 11.8565, Test Loss: 8.1381
# Epoch [88/300], Loss: 12.3426, Test Loss: 7.0611
# Epoch [89/300], Loss: 11.9738, Test Loss: 6.4213
# Epoch [90/300], Loss: 12.5422, Test Loss: 6.4489
# Epoch [91/300], Loss: 12.5962, Test Loss: 6.4622
# Epoch [92/300], Loss: 12.1015, Test Loss: 6.3995
# Epoch [93/300], Loss: 11.8514, Test Loss: 9.2407
# Epoch [94/300], Loss: 12.9865, Test Loss: 6.8364
# Epoch [95/300], Loss: 12.1659, Test Loss: 6.2855
# Epoch [96/300], Loss: 11.6748, Test Loss: 6.8356
# Epoch [97/300], Loss: 11.3013, Test Loss: 6.4800
# Epoch [98/300], Loss: 12.1963, Test Loss: 6.3524
# Epoch [99/300], Loss: 12.2942, Test Loss: 6.3417
# Epoch [100/300], Loss: 12.0511, Test Loss: 6.1209
# Epoch [101/300], Loss: 13.2193, Test Loss: 6.1367
# Epoch [102/300], Loss: 12.0758, Test Loss: 6.4989
# Epoch [103/300], Loss: 11.5891, Test Loss: 6.1909
# Epoch [104/300], Loss: 11.5212, Test Loss: 6.8110
# Epoch [105/300], Loss: 12.2475, Test Loss: 6.5059
# Epoch [106/300], Loss: 12.0947, Test Loss: 6.1956
# Epoch [107/300], Loss: 12.5343, Test Loss: 6.1288
# Epoch [108/300], Loss: 12.3890, Test Loss: 5.9408
# Epoch [109/300], Loss: 12.2921, Test Loss: 6.1600
# Epoch [110/300], Loss: 11.3369, Test Loss: 6.3968
# Epoch [111/300], Loss: 11.1531, Test Loss: 6.1377
# Epoch [112/300], Loss: 12.7109, Test Loss: 6.4787
# Epoch [113/300], Loss: 11.5633, Test Loss: 6.2423
# Epoch [114/300], Loss: 12.5856, Test Loss: 6.5006
# Epoch [115/300], Loss: 11.3150, Test Loss: 6.6727
# Epoch [116/300], Loss: 11.6018, Test Loss: 6.2687
# Epoch [117/300], Loss: 12.3272, Test Loss: 6.6393
# Epoch [118/300], Loss: 11.7337, Test Loss: 6.2947
# Epoch [119/300], Loss: 11.1220, Test Loss: 6.3239
# Epoch [120/300], Loss: 11.7393, Test Loss: 7.7094
# Epoch [121/300], Loss: 12.0925, Test Loss: 6.2513
# Epoch [122/300], Loss: 12.4142, Test Loss: 6.5229
# Epoch [123/300], Loss: 11.4288, Test Loss: 6.9643
# Epoch [124/300], Loss: 11.6692, Test Loss: 6.9401
# Epoch [125/300], Loss: 12.2926, Test Loss: 6.0168
# Epoch [126/300], Loss: 11.3076, Test Loss: 6.2428
# Epoch [127/300], Loss: 12.3023, Test Loss: 6.1997
# Epoch [128/300], Loss: 12.0247, Test Loss: 6.5362
# Epoch [129/300], Loss: 12.5278, Test Loss: 6.4295
# Epoch [130/300], Loss: 11.7764, Test Loss: 10.9246
# Epoch [131/300], Loss: 12.3160, Test Loss: 6.6973
# Epoch [132/300], Loss: 11.6007, Test Loss: 6.4585
# Epoch [133/300], Loss: 11.6602, Test Loss: 6.3005
# Epoch [134/300], Loss: 12.2434, Test Loss: 6.4872
# Epoch [135/300], Loss: 11.8892, Test Loss: 8.2774
# Epoch [136/300], Loss: 11.4930, Test Loss: 6.8196
# Epoch [137/300], Loss: 11.2466, Test Loss: 6.7626
# Epoch [138/300], Loss: 11.5995, Test Loss: 6.8618
# Epoch [139/300], Loss: 11.3384, Test Loss: 6.8826
# Epoch [140/300], Loss: 12.5013, Test Loss: 5.7716
# Epoch [141/300], Loss: 11.1317, Test Loss: 6.0621
# Epoch [142/300], Loss: 11.4713, Test Loss: 6.5446
# Epoch [143/300], Loss: 11.5925, Test Loss: 6.4405
# Epoch [144/300], Loss: 11.5264, Test Loss: 6.2134
# Epoch [145/300], Loss: 11.6028, Test Loss: 6.5966
# Epoch [146/300], Loss: 11.7346, Test Loss: 6.9782
# Epoch [147/300], Loss: 12.4044, Test Loss: 6.2602
# Epoch [148/300], Loss: 11.4223, Test Loss: 6.6240
# Epoch [149/300], Loss: 12.5227, Test Loss: 6.5392
# Epoch [150/300], Loss: 11.3051, Test Loss: 6.5619
# Epoch [151/300], Loss: 12.2463, Test Loss: 6.4399
# Epoch [152/300], Loss: 11.7922, Test Loss: 6.0404
# Epoch [153/300], Loss: 11.9587, Test Loss: 5.9643
# Epoch [154/300], Loss: 11.8708, Test Loss: 6.4311
# Epoch [155/300], Loss: 11.7259, Test Loss: 5.8636
# Epoch [156/300], Loss: 12.3520, Test Loss: 5.7250
# Epoch [157/300], Loss: 11.9052, Test Loss: 6.2519
# Epoch [158/300], Loss: 10.9671, Test Loss: 6.3430
# Epoch [159/300], Loss: 11.6379, Test Loss: 6.2352
# Epoch [160/300], Loss: 11.3763, Test Loss: 6.0165
# Epoch [161/300], Loss: 11.3412, Test Loss: 6.4310
# Epoch [162/300], Loss: 12.3519, Test Loss: 6.3073
# Epoch [163/300], Loss: 11.7727, Test Loss: 6.0839
# Epoch [164/300], Loss: 11.6777, Test Loss: 6.3659
# Epoch [165/300], Loss: 11.5364, Test Loss: 5.8760
# Epoch [166/300], Loss: 12.6540, Test Loss: 5.8056
# Epoch [167/300], Loss: 11.3790, Test Loss: 5.8541
# Epoch [168/300], Loss: 11.2284, Test Loss: 6.2484
# Epoch [169/300], Loss: 11.3129, Test Loss: 8.2207
# Epoch [170/300], Loss: 11.6291, Test Loss: 6.2573
# Epoch [171/300], Loss: 11.9196, Test Loss: 6.0445
# Epoch [172/300], Loss: 11.6803, Test Loss: 7.2694
# Epoch [173/300], Loss: 11.9524, Test Loss: 6.2408
# Epoch [174/300], Loss: 11.9302, Test Loss: 6.6104
# Epoch [175/300], Loss: 12.1913, Test Loss: 8.6041
# Epoch [176/300], Loss: 11.8051, Test Loss: 6.5820
# Epoch [177/300], Loss: 11.7578, Test Loss: 7.3199
# Epoch [178/300], Loss: 11.7665, Test Loss: 6.4353
# Epoch [179/300], Loss: 11.6726, Test Loss: 6.2436
# Epoch [180/300], Loss: 11.6878, Test Loss: 6.2463
# Epoch [181/300], Loss: 10.8924, Test Loss: 6.1432
# Epoch [182/300], Loss: 11.8656, Test Loss: 6.8160
# Epoch [183/300], Loss: 11.7924, Test Loss: 6.4685
# Epoch [184/300], Loss: 11.9735, Test Loss: 6.1756
# Epoch [185/300], Loss: 11.1457, Test Loss: 5.9472
# Epoch [186/300], Loss: 11.6220, Test Loss: 6.8052
# Epoch [187/300], Loss: 11.8346, Test Loss: 6.0091
# Epoch [188/300], Loss: 12.3997, Test Loss: 6.0830
# Epoch [189/300], Loss: 11.5101, Test Loss: 6.3827
# Epoch [190/300], Loss: 11.5828, Test Loss: 6.2421
# Epoch [191/300], Loss: 11.9462, Test Loss: 6.1678
# Epoch [192/300], Loss: 11.7355, Test Loss: 6.1543
# Epoch [193/300], Loss: 11.3720, Test Loss: 6.2462
# Epoch [194/300], Loss: 11.1424, Test Loss: 6.1472
# Epoch [195/300], Loss: 11.6009, Test Loss: 6.1427
# Epoch [196/300], Loss: 11.7675, Test Loss: 6.2719
# Epoch [197/300], Loss: 11.7250, Test Loss: 6.5324
# Epoch [198/300], Loss: 11.3659, Test Loss: 6.3515
# Epoch [199/300], Loss: 11.6049, Test Loss: 6.2919
# Epoch [200/300], Loss: 11.4118, Test Loss: 6.1139
# Epoch [201/300], Loss: 11.1198, Test Loss: 6.4080
# Epoch [202/300], Loss: 11.6341, Test Loss: 6.1509
# Epoch [203/300], Loss: 12.1626, Test Loss: 6.1078
# Epoch [204/300], Loss: 11.6817, Test Loss: 5.9498
# Epoch [205/300], Loss: 12.0208, Test Loss: 5.8906
# Epoch [206/300], Loss: 11.6627, Test Loss: 5.6669
# Epoch [207/300], Loss: 11.7000, Test Loss: 5.8278
# Epoch [208/300], Loss: 11.9153, Test Loss: 6.0234
# Epoch [209/300], Loss: 11.4561, Test Loss: 6.5670
# Epoch [210/300], Loss: 11.1950, Test Loss: 5.9531
# Epoch [211/300], Loss: 11.7703, Test Loss: 5.8819
# Epoch [212/300], Loss: 11.4993, Test Loss: 5.8450
# Epoch [213/300], Loss: 11.5323, Test Loss: 6.0205
# Epoch [214/300], Loss: 11.2106, Test Loss: 5.8477
# Epoch [215/300], Loss: 11.5551, Test Loss: 5.9596
# Epoch [216/300], Loss: 11.3279, Test Loss: 6.0128
# Epoch [217/300], Loss: 11.5125, Test Loss: 7.6161
# Epoch [218/300], Loss: 11.0577, Test Loss: 6.0356
# Epoch [219/300], Loss: 11.9615, Test Loss: 7.5164
# Epoch [220/300], Loss: 11.1036, Test Loss: 6.0100
# Epoch [221/300], Loss: 11.9945, Test Loss: 5.8840
# Epoch [222/300], Loss: 11.7840, Test Loss: 5.6097
# Epoch [223/300], Loss: 13.0044, Test Loss: 5.8816
# Epoch [224/300], Loss: 11.2710, Test Loss: 5.6514
# Epoch [225/300], Loss: 11.5736, Test Loss: 6.0377
# Epoch [226/300], Loss: 11.5627, Test Loss: 5.6821
# Epoch [227/300], Loss: 11.6497, Test Loss: 5.9995
# Epoch [228/300], Loss: 11.2422, Test Loss: 6.0320
# Epoch [229/300], Loss: 11.6270, Test Loss: 6.3048
# Epoch [230/300], Loss: 11.8161, Test Loss: 6.8579
# Epoch [231/300], Loss: 11.1605, Test Loss: 6.6044
# Epoch [232/300], Loss: 11.9197, Test Loss: 10.0047
# Epoch [233/300], Loss: 11.4175, Test Loss: 6.4652
# Epoch [234/300], Loss: 11.3239, Test Loss: 5.9493
# Epoch [235/300], Loss: 11.3667, Test Loss: 5.9146
# Epoch [236/300], Loss: 11.4342, Test Loss: 6.2052
# Epoch [237/300], Loss: 11.5340, Test Loss: 6.3732
# Epoch [238/300], Loss: 11.6428, Test Loss: 6.2614
# Epoch [239/300], Loss: 11.1186, Test Loss: 6.6915
# Epoch [240/300], Loss: 11.7455, Test Loss: 6.2011
# Epoch [241/300], Loss: 12.3031, Test Loss: 6.0150
# Epoch [242/300], Loss: 11.4836, Test Loss: 5.9167
# Epoch [243/300], Loss: 11.1039, Test Loss: 6.2497
# Epoch [244/300], Loss: 11.1898, Test Loss: 6.5465
# Epoch [245/300], Loss: 11.9950, Test Loss: 7.4597
# Epoch [246/300], Loss: 11.5906, Test Loss: 6.0963
# Epoch [247/300], Loss: 11.4739, Test Loss: 6.3532
# Epoch [248/300], Loss: 12.1305, Test Loss: 6.7238
# Epoch [249/300], Loss: 11.7531, Test Loss: 6.1513
# Epoch [250/300], Loss: 11.8936, Test Loss: 5.8519
# Epoch [251/300], Loss: 11.6561, Test Loss: 6.5316
# Epoch [252/300], Loss: 11.4103, Test Loss: 6.3162
# Epoch [253/300], Loss: 11.7003, Test Loss: 6.2833
# Epoch [254/300], Loss: 11.9150, Test Loss: 6.1868
# Epoch [255/300], Loss: 11.8343, Test Loss: 6.1038
# Epoch [256/300], Loss: 11.8966, Test Loss: 5.9075
# Epoch [257/300], Loss: 11.1904, Test Loss: 6.1077
# Epoch [258/300], Loss: 11.2308, Test Loss: 6.1811
# Epoch [259/300], Loss: 11.4039, Test Loss: 6.1258
# Epoch [260/300], Loss: 11.9581, Test Loss: 6.0412
# Epoch [261/300], Loss: 12.0888, Test Loss: 6.0229
# Epoch [262/300], Loss: 11.6763, Test Loss: 6.3112
# Epoch [263/300], Loss: 11.6112, Test Loss: 6.1587
# Epoch [264/300], Loss: 12.0027, Test Loss: 6.6080
# Epoch [265/300], Loss: 11.2901, Test Loss: 5.9116
# Epoch [266/300], Loss: 11.8871, Test Loss: 6.0472
# Epoch [267/300], Loss: 11.4802, Test Loss: 6.5303
# Epoch [268/300], Loss: 11.4739, Test Loss: 6.4087
# Epoch [269/300], Loss: 11.4014, Test Loss: 6.0051
# Epoch [270/300], Loss: 11.3362, Test Loss: 7.1636
# Epoch [271/300], Loss: 11.6338, Test Loss: 6.1473
# Epoch [272/300], Loss: 11.7282, Test Loss: 6.4181
# Epoch [273/300], Loss: 11.4321, Test Loss: 6.5480
# Epoch [274/300], Loss: 11.4762, Test Loss: 23.0518
# Epoch [275/300], Loss: 11.8724, Test Loss: 6.4677
# Epoch [276/300], Loss: 11.5450, Test Loss: 6.5666
# Epoch [277/300], Loss: 12.6434, Test Loss: 6.4104
# Epoch [278/300], Loss: 11.8589, Test Loss: 6.7569
# Epoch [279/300], Loss: 11.5598, Test Loss: 5.9163
# Epoch [280/300], Loss: 11.3360, Test Loss: 6.1637
# Epoch [281/300], Loss: 11.3375, Test Loss: 5.6329
# Epoch [282/300], Loss: 11.3202, Test Loss: 6.0712
# Epoch [283/300], Loss: 11.5567, Test Loss: 5.7917
# Epoch [284/300], Loss: 10.8857, Test Loss: 6.0837
# Epoch [285/300], Loss: 11.2213, Test Loss: 7.0087
# Epoch [286/300], Loss: 11.8015, Test Loss: 7.0922
# Epoch [287/300], Loss: 11.5665, Test Loss: 6.2879
# Epoch [288/300], Loss: 11.1784, Test Loss: 5.8025
# Epoch [289/300], Loss: 11.7201, Test Loss: 5.9509
# Epoch [290/300], Loss: 12.5137, Test Loss: 6.3415
# Epoch [291/300], Loss: 11.1742, Test Loss: 6.0320
# Epoch [292/300], Loss: 11.1614, Test Loss: 6.0935
# Epoch [293/300], Loss: 11.8921, Test Loss: 6.0615
# Epoch [294/300], Loss: 11.6071, Test Loss: 6.0654
# Epoch [295/300], Loss: 11.2618, Test Loss: 5.9912
# Epoch [296/300], Loss: 11.3363, Test Loss: 6.1485
# Epoch [297/300], Loss: 11.5727, Test Loss: 6.2225
# Epoch [298/300], Loss: 11.3658, Test Loss: 5.9972
# Epoch [299/300], Loss: 11.4914, Test Loss: 6.1902
# Epoch [300/300], Loss: 11.5722, Test Loss: 6.1527

# %% [markdown]
# # **MLP test1, lr = 0.01 and 300 epoch**

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
#CPU 혹은 GPU 사용, GPU우선적으로 사용가능
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 데이터 불러오기 (전처리 완료된 데이터라고 가정)
# 이전의 전러치 코드에서 저장한 데이터 사용, val_data는  아마 eval에서 사용예정
train_data = pd.read_csv("train_data.csv")
test_data = pd.read_csv("test_data.csv")

# 특성과 타겟 변수 분리
X_train = train_data.drop(columns=["관측미세먼지"]).values
X_test = test_data.drop(columns=["관측미세먼지"]).values
y_train = train_data["관측미세먼지"].values
y_test = test_data["관측미세먼지"].values

# 각각 train과 test를 알맞게 데이터와 매치, 관측 지점과 관측시간은 숫자형이 아니라서 일단 배제,추후 필요없는 특성이면 drop, 아니라면 다른 전처리 필요
X_train = train_data.drop(columns=["관측미세먼지", "관측지점", "관측시간"]).apply(pd.to_numeric, errors='coerce').fillna(0).values
X_test = test_data.drop(columns=["관측미세먼지", "관측지점", "관측시간"]).apply(pd.to_numeric, errors='coerce').fillna(0).values
y_train = train_data["관측미세먼지"].apply(pd.to_numeric, errors='coerce').fillna(0).values
y_test = test_data["관측미세먼지"].apply(pd.to_numeric, errors='coerce').fillna(0).values

# 스케일링
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# 데이터셋 축소, 시연에서는 10%만 사용, 이후에는 숫자만 조정으로 데이터사이즈 조정,
X_train, _, y_train, _ = train_test_split(X_train, y_train, train_size=0.1, random_state=42)
X_test, _, y_test, _ = train_test_split(X_test, y_test, train_size=0.1, random_state=42)

# Tensor로 변환
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)



# DataLoader 정의
train_dataset = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# 모델 정의
class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(X_train.shape[1], 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 1)
        self.dropout = nn.Dropout(0.2) #overfiting 방지를 위한 drop

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = self.dropout(x)
        x = torch.relu(self.fc2(x))
        x = self.dropout(x)
        x = self.fc3(x)
        return x

    #현재는 미세먼지 농도 "수치"를 예측하는것인 모델이고
    #"수치"를 또 분류하려면 layer를 추가하면됨 ex)softmax(다중분류  ex:저 중 고) , binary(이진분류 ex:저 고)


model = MLP()

# 손실 함수, 옵티마이저 정의
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)   # 0.01로 20인경우 5번째부터 verfiiting 발생  0.001에 epoch 20이 적당해보임

train_losses = []
test_losses = []
# 모델 학습
num_epochs = 300
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for X_batch, y_batch in train_loader:
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * X_batch.size(0)

    epoch_loss = running_loss / len(train_loader.dataset)
    train_losses.append(epoch_loss)  # Append training loss

    #모델 성능 임시 테스트용, 삭제해도 무관
    model.eval()
    with torch.no_grad():
        test_outputs = model(X_test)
        test_loss = criterion(test_outputs, y_test)

    test_losses.append(test_loss.item())  # Append test loss

    print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {epoch_loss:.4f}, Test Loss: {test_loss.item():.4f}')

# Plotting training and test losses
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Test Losses')
plt.legend()
plt.grid(True)
plt.show()


# 예측 함수 정의
def predict(model, X_test):
    model.eval()
    with torch.no_grad():
        y_pred = model(X_test)
    return y_pred.numpy()

# 예측후 결과 저장
predicted_values = predict(model, X_test)

#결과를 npy값으로 저장, 다음파일에서 사용가능
np.save('MLP.npy', predicted_values)
# Out:
# Epoch [1/300], Loss: 88.2575, Test Loss: 10.8607
# Epoch [2/300], Loss: 45.5852, Test Loss: 11.1892
# Epoch [3/300], Loss: 39.9106, Test Loss: 10.1118
# Epoch [4/300], Loss: 32.0028, Test Loss: 14.4048
# Epoch [5/300], Loss: 31.6311, Test Loss: 12.9310
# Epoch [6/300], Loss: 28.8189, Test Loss: 9.2001
# Epoch [7/300], Loss: 24.4543, Test Loss: 10.2919
# Epoch [8/300], Loss: 26.8531, Test Loss: 7.4008
# Epoch [9/300], Loss: 25.2182, Test Loss: 10.9018
# Epoch [10/300], Loss: 22.1211, Test Loss: 6.4596
# Epoch [11/300], Loss: 21.4469, Test Loss: 13.7887
# Epoch [12/300], Loss: 43.2604, Test Loss: 4.7556
# Epoch [13/300], Loss: 26.7996, Test Loss: 14.1906
# Epoch [14/300], Loss: 22.7088, Test Loss: 11.8287
# Epoch [15/300], Loss: 24.9268, Test Loss: 1.7668
# Epoch [16/300], Loss: 21.2377, Test Loss: 10.0835
# Epoch [17/300], Loss: 29.8721, Test Loss: 7.7918
# Epoch [18/300], Loss: 22.4775, Test Loss: 6.9400
# Epoch [19/300], Loss: 20.4484, Test Loss: 11.0444
# Epoch [20/300], Loss: 24.5897, Test Loss: 5.2287
# Epoch [21/300], Loss: 24.1102, Test Loss: 4.0175
# Epoch [22/300], Loss: 28.1818, Test Loss: 5.0119
# Epoch [23/300], Loss: 31.6707, Test Loss: 4.2182
# Epoch [24/300], Loss: 22.1773, Test Loss: 3.2586
# Epoch [25/300], Loss: 21.8731, Test Loss: 4.2795
# Epoch [26/300], Loss: 30.2824, Test Loss: 2.4145
# Epoch [27/300], Loss: 22.2285, Test Loss: 7.3240
# Epoch [28/300], Loss: 23.0795, Test Loss: 8.8967
# Epoch [29/300], Loss: 20.6977, Test Loss: 5.5379
# Epoch [30/300], Loss: 23.4348, Test Loss: 6.7808
# Epoch [31/300], Loss: 24.9415, Test Loss: 10.5876
# Epoch [32/300], Loss: 26.7114, Test Loss: 3.2992
# Epoch [33/300], Loss: 22.5837, Test Loss: 10.2111
# Epoch [34/300], Loss: 22.4818, Test Loss: 6.8897
# Epoch [35/300], Loss: 24.0833, Test Loss: 3.9316
# Epoch [36/300], Loss: 29.4797, Test Loss: 19.5494
# Epoch [37/300], Loss: 26.0851, Test Loss: 8.3614
# Epoch [38/300], Loss: 24.6445, Test Loss: 8.8814
# Epoch [39/300], Loss: 24.3384, Test Loss: 9.1321
# Epoch [40/300], Loss: 23.5055, Test Loss: 26.9076
# Epoch [41/300], Loss: 22.4414, Test Loss: 4.6506
# Epoch [42/300], Loss: 24.6955, Test Loss: 6.1440
# Epoch [43/300], Loss: 22.4295, Test Loss: 4.9783
# Epoch [44/300], Loss: 20.3728, Test Loss: 10.6047
# Epoch [45/300], Loss: 22.5613, Test Loss: 4.7294
# Epoch [46/300], Loss: 23.6331, Test Loss: 8.5024
# Epoch [47/300], Loss: 27.8133, Test Loss: 13.3147
# Epoch [48/300], Loss: 23.5510, Test Loss: 5.3631
# Epoch [49/300], Loss: 20.9772, Test Loss: 4.7168
# Epoch [50/300], Loss: 23.4730, Test Loss: 6.8656
# Epoch [51/300], Loss: 20.2676, Test Loss: 4.9033
# Epoch [52/300], Loss: 31.5127, Test Loss: 6.5527
# Epoch [53/300], Loss: 32.8542, Test Loss: 6.2453
# Epoch [54/300], Loss: 24.5330, Test Loss: 11.5860
# Epoch [55/300], Loss: 22.6459, Test Loss: 11.3086
# Epoch [56/300], Loss: 23.4178, Test Loss: 6.8733
# Epoch [57/300], Loss: 25.4973, Test Loss: 8.1295
# Epoch [58/300], Loss: 23.9572, Test Loss: 8.1714
# Epoch [59/300], Loss: 23.0344, Test Loss: 16.5054
# Epoch [60/300], Loss: 24.3397, Test Loss: 4.9005
# Epoch [61/300], Loss: 29.1131, Test Loss: 4.9649
# Epoch [62/300], Loss: 21.9196, Test Loss: 9.3277
# Epoch [63/300], Loss: 23.2781, Test Loss: 9.7782
# Epoch [64/300], Loss: 26.3973, Test Loss: 6.8006
# Epoch [65/300], Loss: 21.2767, Test Loss: 3.6584
# Epoch [66/300], Loss: 22.7541, Test Loss: 3.6811
# Epoch [67/300], Loss: 22.5875, Test Loss: 8.7988
# Epoch [68/300], Loss: 24.4764, Test Loss: 11.8674
# Epoch [69/300], Loss: 21.3049, Test Loss: 3.6530
# Epoch [70/300], Loss: 21.6773, Test Loss: 8.3123
# Epoch [71/300], Loss: 20.1602, Test Loss: 4.4279
# Epoch [72/300], Loss: 30.8346, Test Loss: 11.9290
# Epoch [73/300], Loss: 20.2958, Test Loss: 4.8039
# Epoch [74/300], Loss: 21.8648, Test Loss: 3.3509
# Epoch [75/300], Loss: 19.7316, Test Loss: 7.4593
# Epoch [76/300], Loss: 19.0536, Test Loss: 14.3572
# Epoch [77/300], Loss: 21.4458, Test Loss: 7.5336
# Epoch [78/300], Loss: 23.3876, Test Loss: 8.2592
# Epoch [79/300], Loss: 25.4301, Test Loss: 4.3445
# Epoch [80/300], Loss: 24.8915, Test Loss: 4.3507
# Epoch [81/300], Loss: 19.6093, Test Loss: 6.6543
# Epoch [82/300], Loss: 21.0747, Test Loss: 5.7945
# Epoch [83/300], Loss: 23.8852, Test Loss: 8.8762
# Epoch [84/300], Loss: 25.6967, Test Loss: 5.7110
# Epoch [85/300], Loss: 20.0432, Test Loss: 4.1996
# Epoch [86/300], Loss: 21.6411, Test Loss: 4.2029
# Epoch [87/300], Loss: 21.2221, Test Loss: 5.0321
# Epoch [88/300], Loss: 19.4614, Test Loss: 4.0866
# Epoch [89/300], Loss: 23.5864, Test Loss: 4.9549
# Epoch [90/300], Loss: 26.3122, Test Loss: 8.2494
# Epoch [91/300], Loss: 21.7189, Test Loss: 36.8947
# Epoch [92/300], Loss: 21.6813, Test Loss: 8.4757
# Epoch [93/300], Loss: 20.3681, Test Loss: 7.0203
# Epoch [94/300], Loss: 20.9546, Test Loss: 12.4669
# Epoch [95/300], Loss: 21.4533, Test Loss: 3.5745
# Epoch [96/300], Loss: 21.2328, Test Loss: 8.3865
# Epoch [97/300], Loss: 20.8139, Test Loss: 4.9353
# Epoch [98/300], Loss: 23.0654, Test Loss: 4.5526
# Epoch [99/300], Loss: 21.3580, Test Loss: 5.8797
# Epoch [100/300], Loss: 23.5734, Test Loss: 4.5860
# Epoch [101/300], Loss: 24.3599, Test Loss: 8.9584
# Epoch [102/300], Loss: 22.6877, Test Loss: 7.3445
# Epoch [103/300], Loss: 22.4178, Test Loss: 5.7863
# Epoch [104/300], Loss: 22.3650, Test Loss: 5.6768
# Epoch [105/300], Loss: 24.0099, Test Loss: 7.6426
# Epoch [106/300], Loss: 21.9412, Test Loss: 6.2036
# Epoch [107/300], Loss: 24.8693, Test Loss: 61.7802
# Epoch [108/300], Loss: 22.2614, Test Loss: 4.8032
# Epoch [109/300], Loss: 19.7568, Test Loss: 7.4494
# Epoch [110/300], Loss: 19.8334, Test Loss: 3.1419
# Epoch [111/300], Loss: 22.9810, Test Loss: 4.3427
# Epoch [112/300], Loss: 19.4432, Test Loss: 7.0223
# Epoch [113/300], Loss: 19.4324, Test Loss: 4.6062
# Epoch [114/300], Loss: 23.8767, Test Loss: 4.9553
# Epoch [115/300], Loss: 19.6751, Test Loss: 4.5716
# Epoch [116/300], Loss: 20.7106, Test Loss: 16.6060
# Epoch [117/300], Loss: 23.0018, Test Loss: 4.4941
# Epoch [118/300], Loss: 23.3422, Test Loss: 2.2762
# Epoch [119/300], Loss: 21.3388, Test Loss: 8.8167
# Epoch [120/300], Loss: 19.3062, Test Loss: 2.1664
# Epoch [121/300], Loss: 20.6541, Test Loss: 5.9752
# Epoch [122/300], Loss: 22.8847, Test Loss: 3.3766
# Epoch [123/300], Loss: 22.9236, Test Loss: 5.0516
# Epoch [124/300], Loss: 21.8151, Test Loss: 7.0829
# Epoch [125/300], Loss: 22.6985, Test Loss: 6.2749
# Epoch [126/300], Loss: 22.6311, Test Loss: 4.7197
# Epoch [127/300], Loss: 23.2250, Test Loss: 6.2991
# Epoch [128/300], Loss: 19.7275, Test Loss: 2.1113
# Epoch [129/300], Loss: 24.8728, Test Loss: 3.7244
# Epoch [130/300], Loss: 20.9304, Test Loss: 7.2157
# Epoch [131/300], Loss: 25.0065, Test Loss: 4.9524
# Epoch [132/300], Loss: 21.8421, Test Loss: 5.0544
# Epoch [133/300], Loss: 21.1206, Test Loss: 7.4814
# Epoch [134/300], Loss: 21.9173, Test Loss: 10.7086
# Epoch [135/300], Loss: 23.4129, Test Loss: 6.4772
# Epoch [136/300], Loss: 20.0387, Test Loss: 3.5524
# Epoch [137/300], Loss: 20.4340, Test Loss: 8.3835
# Epoch [138/300], Loss: 25.3909, Test Loss: 3.4430
# Epoch [139/300], Loss: 22.9364, Test Loss: 6.0260
# Epoch [140/300], Loss: 22.5348, Test Loss: 5.9372
# Epoch [141/300], Loss: 22.1362, Test Loss: 3.5684
# Epoch [142/300], Loss: 21.2168, Test Loss: 5.0539
# Epoch [143/300], Loss: 24.1428, Test Loss: 9.1823
# Epoch [144/300], Loss: 22.9184, Test Loss: 5.3108
# Epoch [145/300], Loss: 25.5505, Test Loss: 5.9885
# Epoch [146/300], Loss: 26.6298, Test Loss: 5.0790
# Epoch [147/300], Loss: 23.4133, Test Loss: 3.0624
# Epoch [148/300], Loss: 24.6942, Test Loss: 5.8307
# Epoch [149/300], Loss: 25.1956, Test Loss: 9.9840
# Epoch [150/300], Loss: 24.9926, Test Loss: 4.3481
# Epoch [151/300], Loss: 20.8840, Test Loss: 11.9053
# Epoch [152/300], Loss: 20.4187, Test Loss: 4.9301
# Epoch [153/300], Loss: 20.7423, Test Loss: 2.1904
# Epoch [154/300], Loss: 18.5564, Test Loss: 11.4554
# Epoch [155/300], Loss: 20.9864, Test Loss: 2.5686
# Epoch [156/300], Loss: 26.9998, Test Loss: 1.6748
# Epoch [157/300], Loss: 21.8520, Test Loss: 6.8954
# Epoch [158/300], Loss: 19.0251, Test Loss: 6.6117
# Epoch [159/300], Loss: 22.1226, Test Loss: 7.3253
# Epoch [160/300], Loss: 20.5478, Test Loss: 4.9906
# Epoch [161/300], Loss: 21.8279, Test Loss: 3.9364
# Epoch [162/300], Loss: 21.1529, Test Loss: 7.2052
# Epoch [163/300], Loss: 21.6139, Test Loss: 3.6664
# Epoch [164/300], Loss: 21.6737, Test Loss: 5.5778
# Epoch [165/300], Loss: 24.8213, Test Loss: 5.0144
# Epoch [166/300], Loss: 25.0451, Test Loss: 9.0008
# Epoch [167/300], Loss: 26.5702, Test Loss: 11.3989
# Epoch [168/300], Loss: 21.2702, Test Loss: 5.4065
# Epoch [169/300], Loss: 20.3582, Test Loss: 3.8655
# Epoch [170/300], Loss: 24.1991, Test Loss: 4.2904
# Epoch [171/300], Loss: 28.2554, Test Loss: 3.6505
# Epoch [172/300], Loss: 19.1490, Test Loss: 3.2607
# Epoch [173/300], Loss: 21.0219, Test Loss: 2.8270
# Epoch [174/300], Loss: 20.8758, Test Loss: 4.7950
# Epoch [175/300], Loss: 26.0177, Test Loss: 4.9110
# Epoch [176/300], Loss: 22.4965, Test Loss: 4.4335
# Epoch [177/300], Loss: 22.0333, Test Loss: 19.6098
# Epoch [178/300], Loss: 20.0239, Test Loss: 4.4835
# Epoch [179/300], Loss: 20.3663, Test Loss: 5.1783
# Epoch [180/300], Loss: 20.8435, Test Loss: 3.5895
# Epoch [181/300], Loss: 20.2752, Test Loss: 6.3522
# Epoch [182/300], Loss: 20.7504, Test Loss: 2.7819
# Epoch [183/300], Loss: 20.1374, Test Loss: 4.7094
# Epoch [184/300], Loss: 18.8828, Test Loss: 5.2276
# Epoch [185/300], Loss: 22.3426, Test Loss: 8.2079
# Epoch [186/300], Loss: 26.1305, Test Loss: 5.8837
# Epoch [187/300], Loss: 24.1578, Test Loss: 7.2752
# Epoch [188/300], Loss: 20.6008, Test Loss: 6.1868
# Epoch [189/300], Loss: 19.2574, Test Loss: 4.4080
# Epoch [190/300], Loss: 20.6450, Test Loss: 11.2870
# Epoch [191/300], Loss: 25.0795, Test Loss: 6.2924
# Epoch [192/300], Loss: 21.3685, Test Loss: 2.9746
# Epoch [193/300], Loss: 24.7193, Test Loss: 3.6824
# Epoch [194/300], Loss: 21.3932, Test Loss: 16.0944
# Epoch [195/300], Loss: 20.2790, Test Loss: 4.7596
# Epoch [196/300], Loss: 21.5120, Test Loss: 7.1650
# Epoch [197/300], Loss: 21.8550, Test Loss: 6.3699
# Epoch [198/300], Loss: 20.1275, Test Loss: 3.6057
# Epoch [199/300], Loss: 24.0889, Test Loss: 9.4942
# Epoch [200/300], Loss: 27.3875, Test Loss: 4.1627
# Epoch [201/300], Loss: 20.6274, Test Loss: 4.1546
# Epoch [202/300], Loss: 24.8397, Test Loss: 5.9949
# Epoch [203/300], Loss: 21.0469, Test Loss: 2.6273
# Epoch [204/300], Loss: 20.7252, Test Loss: 5.0067
# Epoch [205/300], Loss: 25.5262, Test Loss: 3.4769
# Epoch [206/300], Loss: 21.7542, Test Loss: 6.3363
# Epoch [207/300], Loss: 22.2935, Test Loss: 8.7097
# Epoch [208/300], Loss: 22.9810, Test Loss: 3.7414
# Epoch [209/300], Loss: 23.0651, Test Loss: 7.1579
# Epoch [210/300], Loss: 23.6303, Test Loss: 4.4044
# Epoch [211/300], Loss: 20.9088, Test Loss: 3.1967
# Epoch [212/300], Loss: 21.0430, Test Loss: 2.5372
# Epoch [213/300], Loss: 24.9609, Test Loss: 20.4241
# Epoch [214/300], Loss: 27.8200, Test Loss: 6.8111
# Epoch [215/300], Loss: 21.2334, Test Loss: 5.0554
# Epoch [216/300], Loss: 19.8644, Test Loss: 3.3474
# Epoch [217/300], Loss: 20.8535, Test Loss: 4.3638
# Epoch [218/300], Loss: 24.8884, Test Loss: 3.5994
# Epoch [219/300], Loss: 25.8642, Test Loss: 4.7185
# Epoch [220/300], Loss: 24.5338, Test Loss: 5.8376
# Epoch [221/300], Loss: 20.8430, Test Loss: 4.2707
# Epoch [222/300], Loss: 21.0295, Test Loss: 4.9068
# Epoch [223/300], Loss: 19.5907, Test Loss: 4.2696
# Epoch [224/300], Loss: 23.6665, Test Loss: 9.7688
# Epoch [225/300], Loss: 20.9172, Test Loss: 5.3653
# Epoch [226/300], Loss: 18.9318, Test Loss: 7.3132
# Epoch [227/300], Loss: 20.9102, Test Loss: 2.9239
# Epoch [228/300], Loss: 21.4472, Test Loss: 7.7002
# Epoch [229/300], Loss: 22.8034, Test Loss: 6.6941
# Epoch [230/300], Loss: 23.7207, Test Loss: 9.0197
# Epoch [231/300], Loss: 19.8134, Test Loss: 4.7249
# Epoch [232/300], Loss: 22.3283, Test Loss: 5.5434
# Epoch [233/300], Loss: 22.4863, Test Loss: 6.0929
# Epoch [234/300], Loss: 22.1143, Test Loss: 4.9243
# Epoch [235/300], Loss: 23.6312, Test Loss: 5.8745
# Epoch [236/300], Loss: 22.1250, Test Loss: 3.4332
# Epoch [237/300], Loss: 21.9741, Test Loss: 3.4495
# Epoch [238/300], Loss: 20.0629, Test Loss: 5.0524
# Epoch [239/300], Loss: 21.6877, Test Loss: 3.4993
# Epoch [240/300], Loss: 19.9864, Test Loss: 3.2940
# Epoch [241/300], Loss: 21.8645, Test Loss: 10.6157
# Epoch [242/300], Loss: 21.6135, Test Loss: 4.5989
# Epoch [243/300], Loss: 19.0326, Test Loss: 4.2994
# Epoch [244/300], Loss: 27.3781, Test Loss: 3.9413
# Epoch [245/300], Loss: 25.9087, Test Loss: 3.7337
# Epoch [246/300], Loss: 19.7745, Test Loss: 4.3832
# Epoch [247/300], Loss: 25.5246, Test Loss: 3.9698
# Epoch [248/300], Loss: 21.6173, Test Loss: 4.6906
# Epoch [249/300], Loss: 26.5237, Test Loss: 4.8373
# Epoch [250/300], Loss: 20.1315, Test Loss: 3.3344
# Epoch [251/300], Loss: 20.4479, Test Loss: 2.4132
# Epoch [252/300], Loss: 21.5657, Test Loss: 8.5459
# Epoch [253/300], Loss: 22.1488, Test Loss: 3.8984
# Epoch [254/300], Loss: 21.6509, Test Loss: 4.6761
# Epoch [255/300], Loss: 20.1129, Test Loss: 6.0557
# Epoch [256/300], Loss: 20.2510, Test Loss: 5.4930
# Epoch [257/300], Loss: 20.9735, Test Loss: 6.5319
# Epoch [258/300], Loss: 21.1486, Test Loss: 6.1024
# Epoch [259/300], Loss: 25.9828, Test Loss: 5.5861
# Epoch [260/300], Loss: 22.7701, Test Loss: 5.5399
# Epoch [261/300], Loss: 22.4139, Test Loss: 2.2212
# Epoch [262/300], Loss: 21.9132, Test Loss: 5.8840
# Epoch [263/300], Loss: 20.7709, Test Loss: 4.7388
# Epoch [264/300], Loss: 22.0696, Test Loss: 4.1475
# Epoch [265/300], Loss: 20.6321, Test Loss: 10.3165
# Epoch [266/300], Loss: 24.7989, Test Loss: 6.1078
# Epoch [267/300], Loss: 25.8432, Test Loss: 4.7439
# Epoch [268/300], Loss: 19.0682, Test Loss: 4.5941
# Epoch [269/300], Loss: 22.0598, Test Loss: 4.8035
# Epoch [270/300], Loss: 21.5216, Test Loss: 6.2939
# Epoch [271/300], Loss: 20.7006, Test Loss: 20.0822
# Epoch [272/300], Loss: 21.0127, Test Loss: 7.6851
# Epoch [273/300], Loss: 21.2524, Test Loss: 3.3672
# Epoch [274/300], Loss: 19.2918, Test Loss: 3.9129
# Epoch [275/300], Loss: 20.7774, Test Loss: 7.0687
# Epoch [276/300], Loss: 21.1023, Test Loss: 6.6439
# Epoch [277/300], Loss: 22.0905, Test Loss: 8.0556
# Epoch [278/300], Loss: 22.1928, Test Loss: 8.0637
# Epoch [279/300], Loss: 21.5104, Test Loss: 3.3077
# Epoch [280/300], Loss: 21.9850, Test Loss: 6.5315
# Epoch [281/300], Loss: 20.2620, Test Loss: 6.2510
# Epoch [282/300], Loss: 19.7878, Test Loss: 4.0936
# Epoch [283/300], Loss: 20.1174, Test Loss: 7.1902
# Epoch [284/300], Loss: 21.6115, Test Loss: 5.4573
# Epoch [285/300], Loss: 22.3524, Test Loss: 4.6779
# Epoch [286/300], Loss: 19.4840, Test Loss: 3.0747
# Epoch [287/300], Loss: 20.8483, Test Loss: 4.6968
# Epoch [288/300], Loss: 21.3465, Test Loss: 8.2749
# Epoch [289/300], Loss: 20.7451, Test Loss: 4.5969
# Epoch [290/300], Loss: 22.2052, Test Loss: 5.9460
# Epoch [291/300], Loss: 19.8264, Test Loss: 4.0012
# Epoch [292/300], Loss: 22.8572, Test Loss: 15.8536
# Epoch [293/300], Loss: 19.9822, Test Loss: 7.4397
# Epoch [294/300], Loss: 19.8572, Test Loss: 4.3553
# Epoch [295/300], Loss: 19.7727, Test Loss: 3.3353
# Epoch [296/300], Loss: 21.6286, Test Loss: 5.4026
# Epoch [297/300], Loss: 21.2860, Test Loss: 3.7073
# Epoch [298/300], Loss: 20.7343, Test Loss: 3.5811
# Epoch [299/300], Loss: 21.7507, Test Loss: 4.4936
# Epoch [300/300], Loss: 20.8072, Test Loss: 3.1144
